# %% [markdown]
# Bob has started his own mobile company. He wants to give tough fight to big companies like Apple,Samsung etc.
#
# He does not know how to estimate price of mobiles his company creates. In this competitive mobile phone market you cannot simply assume things. To solve this problem he collects sales data of mobile phones of various companies.
#
# Bob wants to find out some relation between features of a mobile phone(eg:- RAM,Internal Memory etc) and its selling price. But he is not so good at Machine Learning. So he needs your help to solve this problem.
#
# In this problem you do not have to predict actual price but a price range indicating how high the price is

# %%
import pandas as pd
import numpy as np
from sklearn.svm import LinearSVC
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, RocCurveDisplay, roc_curve
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/mobile-price-classification/train.csv")

# %%
df.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# 0        0             0     1            1
# 1        1             1     0            2
# 2        1             1     0            2
# 3        1             0     0            2
# 4        1             1     0            1
#
# [5 rows x 21 columns]

# %%
len(df)
# Out:
# 2000

# %%
df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
X = df.drop("price_range", axis=1)
y = df["price_range"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
clf = LinearSVC(max_iter=1000, dual="auto").fit(X_train, y_train)

# %%
clf.score(X_test, y_test)
# Out:
# 0.78

# %%
params = {
    "C": [0.9, 0.7, 0.4],
    "max_iter": [2000, 3000, 4000]
}

# %%
rs_clf = RandomizedSearchCV(clf, params, n_iter=5, cv=5).fit(X_train, y_train)

# %%
rs_clf.best_params_
# Out:
# {'max_iter': 2000, 'C': 0.9}

# %%
rs_clf.score(X_test, y_test)
# Out:
# 0.7825

# %%
random_forst = RandomForestClassifier().fit(X_train, y_train)
random_forst.score(X_test, y_test)
# Out:
# 0.855

# %%
y_preds = random_forst.predict(X_test)

# %%
# Metrics
cm = confusion_matrix(y_test, y_preds)
sn.heatmap(cm, annot=True);

# %%
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.94      0.90        81
#            1       0.79      0.81      0.80       110
#            2       0.85      0.75      0.80       107
#            3       0.92      0.95      0.93       102
#
#     accuracy                           0.85       400
#    macro avg       0.86      0.86      0.86       400
# weighted avg       0.85      0.85      0.85       400

# %%
y_proba = random_forst.predict_proba(X_test)[:, 1]

# %%
df_test = pd.read_csv("../data/mobile-price-classification/test.csv").drop("id", axis=1)
df_test.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043     1          1.8         1  14       0           5    0.1
# 1            841     1          0.5         1   4       1          61    0.8
# 2           1807     1          2.8         0   1       0          27    0.9
# 3           1546     0          0.5         1  18       1          25    0.5
# 4           1434     0          1.4         0  11       1          49    0.5
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        193        3  16        226      1412  3476    12     7          2
# 1        191        5  12        746       857  3895     6     0          7
# 2        186        3   4       1270      1366  2396    17    10         10
# 3         96        8  20        295      1752  3893    10     0          7
# 4        108        6  18        749       810  1773    15     8          7
#
#    three_g  touch_screen  wifi
# 0        0             1     0
# 1        1             0     0
# 2        0             1     1
# 3        1             1     0
# 4        1             0     1

# %%
y_preds = random_forst.predict(df_test)

# %%
df_test["price_range"] = pd.Series(y_preds)

# %%
df_test.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0           1043     1          1.8         1  14       0           5    0.1
# 1            841     1          0.5         1   4       1          61    0.8
# 2           1807     1          2.8         0   1       0          27    0.9
# 3           1546     0          0.5         1  18       1          25    0.5
# 4           1434     0          1.4         0  11       1          49    0.5
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        193        3  ...        226      1412  3476    12     7          2
# 1        191        5  ...        746       857  3895     6     0          7
# 2        186        3  ...       1270      1366  2396    17    10         10
# 3         96        8  ...        295      1752  3893    10     0          7
# 4        108        6  ...        749       810  1773    15     8          7
#
#    three_g  touch_screen  wifi  price_range
# 0        0             1     0            3
# 1        1             0     0            3
# 2        0             1     1            2
# 3        1             1     0            3
# 4        1             0     1            1
#
# [5 rows x 21 columns]

# %%
df_test.sort_values(by="price_range", ascending=False)
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0             1043     1          1.8         1  14       0           5
# 576           1464     0          0.5         1   1       1           6
# 633           1216     0          1.7         1   1       0          26
# 247           1759     0          0.5         1   9       0          58
# 246           1477     1          1.7         0   1       0          15
# ..             ...   ...          ...       ...  ..     ...         ...
# 682            524     0          0.9         1   8       1          10
# 681           1857     0          1.9         1   0       0          62
# 216           1038     1          0.5         1   1       0          48
# 218           1698     0          0.5         0   6       1          21
# 705            734     1          2.7         1   1       1          32
#
#      m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# 0      0.1        193        3  ...        226      1412  3476    12     7
# 576    0.4         97        5  ...        303       701  3725     9     1
# 633    0.7        116        3  ...        957      1811  3607    10     0
# 247    0.2        101        2  ...        510       615  3428    17     0
# 246    0.4        178        8  ...       1381      1459  2684    18    13
# ..     ...        ...      ...  ...        ...       ...   ...   ...   ...
# 682    0.1         85        7  ...        287       655   625     6     0
# 681    0.6        147        1  ...       1028      1465   336    19     0
# 216    0.2         99        6  ...         83      1103  1073     5     4
# 218    0.1        196        7  ...        614      1254   778     7     3
# 705    0.8         93        8  ...        138      1042   714    13     7
#
#      talk_time  three_g  touch_screen  wifi  price_range
# 0            2        0             1     0            3
# 576          6        1             0     0            3
# 633         17        1             0     0            3
# 247          9        1             1     0            3
# 246          8        1             1     1            3
# ..         ...      ...           ...   ...          ...
# 682          4        1             1     1            0
# 681          5        0             0     0            0
# 216          2        0             0     1            0
# 218          3        1             1     1            0
# 705         16        1             0     1            0
#
# [1000 rows x 21 columns]

# %%
df_test["price_range"].value_counts()
# Out:
# price_range
# 0    264
# 3    258
# 1    243
# 2    235
# Name: count, dtype: int64
