# %%
# https://github.com/mrdbourke/zero-to-mastery-ml/blob/master/section-2-data-science-and-ml-tools/pandas-exercises.ipynb
import pandas as pd

# %%
colors = pd.Series(["Red", "Yellow", "Blue"])

# %%
colors

# %%
cars = pd.Series(["Vw", "Honda", "Toyota"])
cars

# %%
df = pd.DataFrame({
    "Cars": cars,
    "Colors": colors
})

# %%
df

# %%
car_sales = pd.read_csv("7.1 car-sales.csv")
car_sales

# %%
df.to_csv("My-car-csv.csv")

# %%
car_sales.info()

# %%
car_sales.describe()

# %%
car_sales.dtypes

# %%
fuel_economy = [7.5, 5.6, 4.7, 9.0, 8.5, 9.5, 7.7, 3.0, 5.5, 4.0]
car_sales["Fuel economy"] = fuel_economy

# %%
car_sales

# %%
car_sales["Fuel economy"].mean()

# %%
car_sales["Fuel economy"].sum()

# %%
list(car_sales)

# %%
len(car_sales)

# %%
car_sales.loc[:4]car

# %%
car_sales[:6]

# %%
car_sales.tail(5)

# %%
car_sales.iloc[3]

# %%
car_sales["Odometer (KM)"].mean()

# %%
highest_odometer = car_sales[car_sales["Odometer (KM)"] > 100000]

# %%
highest_odometer

# %%
car_sales.crosstab(["Doors", "Make"])

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])

# %%
grouped_data = car_sales.groupby("Make")

# %%
grouped_data.mean() # ERROR

# %%
car_sales["Odometer (KM)"].plot()

# %%
car_sales["Odometer (KM)"].hist()

# %%
car_sales["Price"] = (car_sales["Price"].replace("[\$\,\.]", "", regex=True).astype(int)) // 100

# %%
car_sales["Price"].info()

# %%
car_sales.Price.plot()

# %%
car_sales.rename(str.lower, axis="columns")

# %%
missing_data = pd.read_csv("9.2 car-sales-missing-data.csv")
missing_data
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
missing_data["Odometer"].fillna(missing_data["Odometer"].mean(), inplace=True)

# %%
missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
missing_data.dropna(inplace=True)
missing_data
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
missing_data["Seats"] = 5

# %%
missing_data
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000      5
# 1   Honda    Red   87899.000000    4.0   $5,000      5
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5
# 3     BMW  Black   11179.000000    5.0  $22,000      5
# 4  Nissan  White  213095.000000    4.0   $3,500      5
# 5  Toyota  Green   92302.666667    4.0   $4,500      5

# %%
engine_size = [1.3, 1.4, 1.6, 1.8, 2.0, 4.8]
missing_data["Engine size"] = engine_size

# %%
missing_data
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine size
# 0  Toyota  White  150043.000000    4.0   $4,000      5          1.3
# 1   Honda    Red   87899.000000    4.0   $5,000      5          1.4
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5          1.6
# 3     BMW  Black   11179.000000    5.0  $22,000      5          1.8
# 4  Nissan  White  213095.000000    4.0   $3,500      5          2.0
# 5  Toyota  Green   92302.666667    4.0   $4,500      5          4.8

# %%
price_km_in_dollars = [1, 1.5, 2, 2.5, 3, 5.5]
missing_data["Km price ($)"] = price_km_in_dollars
missing_data
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine size  \
# 0  Toyota  White  150043.000000    4.0   $4,000      5          1.3
# 1   Honda    Red   87899.000000    4.0   $5,000      5          1.4
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5          1.6
# 3     BMW  Black   11179.000000    5.0  $22,000      5          1.8
# 4  Nissan  White  213095.000000    4.0   $3,500      5          2.0
# 5  Toyota  Green   92302.666667    4.0   $4,500      5          4.8
#
#    Km price ($)
# 0           1.0
# 1           1.5
# 2           2.0
# 3           2.5
# 4           3.0
# 5           5.5

# %%
missing_data.drop("Km price ($)", axis=1, inplace=True)
missing_data
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine size
# 0  Toyota  White  150043.000000    4.0   $4,000      5          1.3
# 1   Honda    Red   87899.000000    4.0   $5,000      5          1.4
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5          1.6
# 3     BMW  Black   11179.000000    5.0  $22,000      5          1.8
# 4  Nissan  White  213095.000000    4.0   $3,500      5          2.0
# 5  Toyota  Green   92302.666667    4.0   $4,500      5          4.8

# %%
shuffle_data = missing_data.sample(frac=1, ignore_index=True)
shuffle_data
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine size
# 0   Honda    Red   87899.000000    4.0   $5,000      5          1.4
# 1  Nissan  White  213095.000000    4.0   $3,500      5          2.0
# 2  Toyota  Green   92302.666667    4.0   $4,500      5          4.8
# 3     BMW  Black   11179.000000    5.0  $22,000      5          1.8
# 4  Toyota   Blue   92302.666667    3.0   $7,000      5          1.6
# 5  Toyota  White  150043.000000    4.0   $4,000      5          1.3

# %%
car_sales = pd.read_csv("7.1 car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"] * 0.62
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White       93026.66      4   $4,000.00
# 1   Honda    Red       54497.38      4   $5,000.00
# 2  Toyota   Blue       20180.38      3   $7,000.00
# 3     BMW  Black        6930.98      5  $22,000.00
# 4  Nissan  White      132118.90      4   $3,500.00
# 5  Toyota  Green       61512.06      4   $4,500.00
# 6   Honda   Blue       28332.76      4   $7,500.00
# 7   Honda   Blue       33937.56      4   $7,000.00
# 8  Toyota  White       37200.00      4   $6,250.00
# 9  Nissan  White       19592.00      4   $9,700.00

# %%
car_sales.rename(columns={"Odometer (KM)": "Odometer (M)"})
# Out:
#      Make Colour  Odometer (M)  Doors       Price
# 0  Toyota  White      93026.66      4   $4,000.00
# 1   Honda    Red      54497.38      4   $5,000.00
# 2  Toyota   Blue      20180.38      3   $7,000.00
# 3     BMW  Black       6930.98      5  $22,000.00
# 4  Nissan  White     132118.90      4   $3,500.00
# 5  Toyota  Green      61512.06      4   $4,500.00
# 6   Honda   Blue      28332.76      4   $7,500.00
# 7   Honda   Blue      33937.56      4   $7,000.00
# 8  Toyota  White      37200.00      4   $6,250.00
# 9  Nissan  White      19592.00      4   $9,700.00
