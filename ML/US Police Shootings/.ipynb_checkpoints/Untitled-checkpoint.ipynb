# %% [markdown]
# ## Context
# In the recent killings, a hot topic came into being, "Racism".
# So, I chose to gather some data to take out some insights and analyze the story around racism in America.
# I downloaded the raw data from kaggle and prepared it for visualization while correcting values, handling missing content, normalization and categorization
#
# ## Content
# It contains basic data about people like their name, age, gender and race. Along with it, is the shooting/killing information, like date of event, where it happened? how they were shot? did they attack? Were they holding weapons? Did they show any mental illness? Was the policeman wearing a camera/was the incident recorded? Did the suspect flee? Apart from that, a category column holds type of weapon used by the suspect

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams["figure.figsize"] = (14, 8)

# %%
df = pd.read_csv("../data/shootings.csv", parse_dates=["date"])

# %%
def fix_dates(df):
    df["year"] = df["date"].dt.year
    df["Month"] = df["date"].dt.month
    df["Day"] = df["date"].dt.day

    df.drop("date", axis=1, inplace=True)

    return df

# %%
df = fix_dates(df)

# %%
df.drop(["id","name"], axis=1, inplace=True)

# %%
df.head()
# Out:
#     manner_of_death       armed   age gender      race           city state  \
# 0              shot         gun  53.0      M     Asian        Shelton    WA
# 1              shot         gun  47.0      M     White          Aloha    OR
# 2  shot and Tasered     unarmed  23.0      M  Hispanic        Wichita    KS
# 3              shot  toy weapon  32.0      M     White  San Francisco    CA
# 4              shot    nail gun  39.0      M  Hispanic          Evans    CO
#
#    signs_of_mental_illness threat_level         flee  body_camera  \
# 0                     True       attack  Not fleeing        False
# 1                    False       attack  Not fleeing        False
# 2                    False        other  Not fleeing        False
# 3                     True       attack  Not fleeing        False
# 4                    False       attack  Not fleeing        False
#
#            arms_category  year  Month  Day
# 0                   Guns  2015      1    2
# 1                   Guns  2015      1    2
# 2                Unarmed  2015      1    3
# 3  Other unusual objects  2015      1    4
# 4       Piercing objects  2015      1    4

# %%
df.shape
# Out:
# (4895, 15)

# %%
df.isna().mean()
# Out:
# manner_of_death            0.0
# armed                      0.0
# age                        0.0
# gender                     0.0
# race                       0.0
# city                       0.0
# state                      0.0
# signs_of_mental_illness    0.0
# threat_level               0.0
# flee                       0.0
# body_camera                0.0
# arms_category              0.0
# year                       0.0
# Month                      0.0
# Day                        0.0
# dtype: float64

# %%
df.dtypes
# Out:
# manner_of_death             object
# armed                       object
# age                        float64
# gender                      object
# race                        object
# city                        object
# state                       object
# signs_of_mental_illness       bool
# threat_level                object
# flee                        object
# body_camera                   bool
# arms_category               object
# year                         int32
# Month                        int32
# Day                          int32
# dtype: object

# %%
plt.title("Age")
sns.histplot(data=df, x="age", kde=True, hue="manner_of_death");

# %%
plt.title("Category of weapons")
sns.histplot(data=df, x="arms_category", hue="threat_level")
plt.xticks(rotation=45);

# %%
plt.title("Category of weapons")
sns.histplot(data=df, x="arms_category", hue="manner_of_death")
plt.xticks(rotation=45);
