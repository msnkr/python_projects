# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# I love the hex plots

# %%
sns.jointplot(x=tips.tip, y=tips.total_bill, palette="pastel", kind="hex", color="Salmon");

# %%
sns.jointplot(x=tips.tip, y=tips.total_bill, hue=tips.smoker, kind="kde", fill=True, palette="pastel");

# %%
sns.scatterplot(x=tips.tip, y=tips.total_bill, hue=tips.day, palette="pastel");

# %%
sns.histplot(x=tips.tip, hue=tips.sex, palette="pastel", kde=True);

# %% [markdown]
# I like this plot

# %%
sns.boxplot(x=tips.day, y=tips.total_bill, hue=tips.sex, palette="pastel", fill=False, gap=.2);

# %%
df = sns.load_dataset("penguins")
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.scatterplot(x=df.body_mass_g, y=df.bill_length_mm, hue=df.sex, palette="pastel");
