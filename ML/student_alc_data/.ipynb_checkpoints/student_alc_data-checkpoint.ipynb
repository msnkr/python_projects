# %%
import pandas as pd

df = pd.read_csv("student-mat.csv")

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
grouped_data = df.groupby("sex")["famrel"].sum()

# %%
import matplotlib.pyplot as plt

grouped_data.plot(kind="bar", color=["pink", "blue"])
plt.title("Relationships")
plt.xlabel("Sex")
plt.ylabel("Family Score")
plt.show()

# %%
grouped_data = df.groupby("sex")["Dalc"].sum()
grouped_data.plot(kind="bar", color=["pink", "blue"])
plt.title("Who drinks more on the weekend")
plt.xlabel("Sex")
plt.ylabel("Weekend")
plt.show()

# %%
grouped_data = df.groupby("sex")["failures"].sum()
grouped_data.plot(kind="bar", color=["pink", "blue"])
plt.title("More failures")
plt.xlabel("Sex")
plt.ylabel("Failures")
plt.show()

# %%
graded_variables = ["G1", "G2", "G3", "age", "studytime", "failures", "absences", "traveltime"]

# %%
df_subset = df[graded_variables]

# %%
df_subset
# Out:
#      G1  G2  G3  age  studytime  failures  absences  traveltime
# 0     5   6   6   18          2         0         6           2
# 1     5   5   6   17          2         0         4           1
# 2     7   8  10   15          2         3        10           1
# 3    15  14  15   15          3         0         2           1
# 4     6  10  10   16          2         0         4           1
# ..   ..  ..  ..  ...        ...       ...       ...         ...
# 390   9   9   9   20          2         2        11           1
# 391  14  16  16   17          1         0         3           2
# 392  10   8   7   21          1         3         3           1
# 393  11  12  10   18          1         0         0           3
# 394   8   9   9   19          1         0         5           1
#
# [395 rows x 8 columns]

# %%
correlation_matrix = df_subset.corr()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidth=.5)
plt.title("Correlation Matrix")
plt.show()

# %%
sns.pairplot(df_subset, vars=["G1", "G2", "G3", "age", "studytime", "failures", "absences", "traveltime"])
plt.suptitle("'Pairplot of Grades and Numeric Variables', y=1.02")
plt.show()
# Out:
# C:\Users\Digital\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
