# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("match_results.csv", parse_dates=["Date"])

# %%
data["Month"] = data["Date"].dt.month
data["Day"] = data["Date"].dt.day
data["Year"] = data["Date"].dt.year

# %%
data.drop(["Category", "Date"], axis=1, inplace=True)

# %%
data.dtypes
# Out:
# Name                 object
# Division             object
# Match Points        float64
# Match Percentage    float64
# Month                 int32
# Day                   int32
# Year                  int32
# dtype: object

# %%
data.head()
# Out:
#                       Name Division  Match Points  Match Percentage  Month  \
# 0      De Gouveia, Roberto       PO      230.0000          100.0000      5
# 1              Plein, Noah        P      225.5229           98.0534      5
# 2     Goncalves, Francisco       PO      218.2286           94.8820      5
# 3  De Gouveia, Roberto (P)        P      180.6650           78.5500      5
# 4          Moolman, Adrian        P      173.7252           75.5327      5
#
#    Day  Year
# 0   28  2025
# 1   28  2025
# 2   28  2025
# 3   28  2025
# 4   28  2025

# %%
sns.scatterplot(data=data, x="Match Percentage", y="Match Points", hue="Day")
# Out:
# <Axes: xlabel='Match Percentage', ylabel='Match Points'>
