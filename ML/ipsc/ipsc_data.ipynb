# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams["figure.figsize"] = (14, 6)

# %%
data = pd.read_csv("match_results_combined.csv", parse_dates=["date"])

# %%
len(data)
# Out:
# 1373

# %%
len(data["name"].unique())
# Out:
# 141
