# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("match_results.csv", parse_dates=["Date"])

# %%
data.head()
data.drop("Category", axis=1, inplace=True)

# %%
data.head()
# Out:
#         Date                     Name Division  Match Points  Match Percentage
# 0 2025-05-28      De Gouveia, Roberto       PO      230.0000          100.0000
# 1 2025-05-28              Plein, Noah        P      225.5229           98.0534
# 2 2025-05-28     Goncalves, Francisco       PO      218.2286           94.8820
# 3 2025-05-28  De Gouveia, Roberto (P)        P      180.6650           78.5500
# 4 2025-05-28          Moolman, Adrian        P      173.7252           75.5327

# %%
data["Month"] = data["Date"].dt.month

# %%
data.dtypes
# Out:
# Date                datetime64[ns]
# Name                        object
# Division                    object
# Match Points               float64
# Match Percentage           float64
# Month                        int32
# dtype: object
