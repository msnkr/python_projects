# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams["figure.figsize"] = (14, 6)

# %%
data = pd.read_csv("sorted_stages.csv", parse_dates=["date"])
