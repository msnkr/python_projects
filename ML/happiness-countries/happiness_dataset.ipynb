# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_csv("../data/happiness.csv")
df.tail()
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 150     3.398970                  0.368746  0.945707
# 151     3.260331                  0.777153  0.396103
# 152     3.236570                  0.511136  1.041990
# 153     2.735310                  0.091623  0.629794
# 154     2.521116                  0.000000  0.000000
#
#      Health..Life.Expectancy.   Freedom  Generosity  \
# 150                  0.326425  0.581844    0.252756
# 151                  0.500533  0.081539    0.493664
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
df["Happiness.Rank"].mean()
# Out:
# 78.0

# %%
mid = df[df["Happiness.Rank"] < df["Happiness.Rank"].mean()][:30]
len(mid)
# Out:
# 30

# %%
fig, ax1 = plt.subplots(nrows=1, ncols=1, figsize=(12, 8))
ax_bar = ax1.barh(mid["Country"], mid["Happiness.Score"], height=0.5, )

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 28))

ax.barh(df["Country"], df["Trust..Government.Corruption."], height=0.6, color="lightgreen");

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 28))

ax.barh(df["Country"], df["Dystopia.Residual"], height=0.6, color="lightblue");

# %%
df.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
happiness = df[df["Happiness.Score"] > df["Happiness.Score"].mean()]

# %%
happiness
# Out:
#                     Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                    Norway               1            7.537      7.594445
# 1                   Denmark               2            7.522      7.581728
# 2                   Iceland               3            7.504      7.622030
# 3               Switzerland               4            7.494      7.561772
# 4                   Finland               5            7.469      7.527542
# ..                      ...             ...              ...           ...
# 68                   Turkey              69            5.500      5.594865
# 69                 Paraguay              70            5.493      5.577381
# 70  Hong Kong S.A.R., China              71            5.472      5.549594
# 71              Philippines              72            5.430      5.545335
# 72                   Serbia              73            5.395      5.491570
#
# ...

# %%
len(happiness)
# Out:
# 73

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 18))
ax.barh(happiness["Country"], happiness["Generosity"], color="pink");

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 18))
ax.barh(happiness["Country"], happiness["Economy..GDP.per.Capita."], color="orange");

# %%
happiness.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12, 40))
ax.barh(df["Country"], df["Health..Life.Expectancy."], color="red")
# Out:
# <BarContainer object of 155 artists>

# %%
df.tail()
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 150                    Rwanda             151            3.471      3.543030
# 151                     Syria             152            3.462      3.663669
# 152                  Tanzania             153            3.349      3.461430
# 153                   Burundi             154            2.905      3.074690
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 150     3.398970                  0.368746  0.945707
# 151     3.260331                  0.777153  0.396103
# 152     3.236570                  0.511136  1.041990
# 153     2.735310                  0.091623  0.629794
# 154     2.521116                  0.000000  0.000000
#
#      Health..Life.Expectancy.   Freedom  Generosity  \
# 150                  0.326425  0.581844    0.252756
# 151                  0.500533  0.081539    0.493664
# ...

# %%
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
ax1_bar = ax1.bar(df["Country"].loc[0], df["Happiness.Score"].loc[0], )
ax1_bar = ax1.bar(df["Country"].loc[len(df) -1], df["Happiness.Score"].loc[len(df) -1]);
ax1.set(xlabel="Country", ylabel="Happiness Score")

ax2_bar = ax2.bar(df["Country"].loc[0], df["Health..Life.Expectancy."].loc[0])
ax2_bar = ax2.bar(df["Country"].loc[len(df) -1], df["Health..Life.Expectancy."].loc[len(df) -1])
ax2.set(xlabel="Country", ylabel="Life expectancy");

# %%
_, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))
ax1_bar = ax1.bar(df["Country"].loc[len(df) - 1], df["Health..Life.Expectancy."].loc[len(df) - 1])
ax1_bar = ax1.bar(df["Country"].loc[len(df) - 2], df["Health..Life.Expectancy."].loc[len(df) - 2])
ax1.set(xlabel="Country", ylabel="Life expectancy")

ax2_bar = ax2.bar(df["Country"].loc[len(df) - 1], df["Trust..Government.Corruption."].loc[len(df) - 1])
ax2_bar = ax2.bar(df["Country"].loc[len(df) - 2], df["Trust..Government.Corruption."].loc[len(df) - 2])
ax2.set(xlabel="Country", ylabel="Government Corruption");
