# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt

# %%
# Get the data

breast = load_breast_cancer()
breast_cancer = pd.DataFrame(breast["data"], columns=breast["feature_names"])
breast_cancer["target"] = breast["target"]

breast_cancer.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
# Sort the data
X = breast_cancer.drop("target", axis=1)
y = breast_cancer["target"]

# %%
# Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
# Instantiate the model
clf = RandomForestClassifier().fit(X_train, y_train)

# %%
# Score
# Default mean accuracy
clf.score(X_test, y_test)
# Out:
# 0.9605263157894737

# %%
# Evaluate different metrics
y_preds = clf.predict(X_test)
y_preds[:10]
# Out:
# array([1, 1, 1, 1, 1, 0, 1, 1, 0, 1])

# %%
print("Accuracy Score: {}".format(accuracy_score(y_test, y_preds)))
print("Precision Score: {}".format(precision_score(y_test, y_preds)))
print("Recall Score: {}".format(recall_score(y_test, y_preds)))
print("F1 Score: {}".format(f1_score(y_test, y_preds)))
# Out:
# Accuracy Score: 0.9605263157894737
# Precision Score: 0.9568345323741008
# Recall Score: 0.9779411764705882
# F1 Score: 0.9672727272727273

# %%
cross_val_score(clf, X, y)
# Out:
# array([0.92982456, 0.94736842, 0.98245614, 0.97368421, 0.96460177])

# %%
np.mean(cross_val_score(clf, X, y))
# Out:
# 0.9578481602235678

# %%
X_test.head()
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 412        9.397         21.68           59.75      268.8          0.07969
# 431       12.400         17.68           81.47      467.8          0.10540
# 410       11.360         17.57           72.49      399.8          0.08858
# 153       11.150         13.08           70.87      381.9          0.09754
# 242       11.300         18.19           73.93      389.4          0.09592
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 412           0.06053         0.03735             0.005128         0.1274
# 431           0.13160         0.07741             0.027990         0.1811
# 410           0.05313         0.02783             0.021000         0.1601
# 153           0.05113         0.01982             0.017860         0.1830
# 242           0.13250         0.15480             0.028540         0.2054
#
#      mean fractal dimension  ...  worst radius  worst texture  \
# ...

# %%
breast_cancer
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
# ...

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 5))

ax1_scatter = ax1.scatter(x=breast_cancer["mean radius"], 
            y=breast_cancer["mean symmetry"], 
            c=breast_cancer["target"])

ax2_scatter = ax2.scatter(x=breast_cancer["worst radius"], 
            y=breast_cancer["worst symmetry"], 
            c=breast_cancer["target"])

ax1.legend(*ax1_scatter.legend_elements())
ax2.legend(*ax1_scatter.legend_elements())

ax1.set(xlabel="Mean",
       ylabel="Mean")

ax2.set(xlabel="Worst",
       ylabel="Worst");

fig.set(xlabel="SymmeWorsttry")
