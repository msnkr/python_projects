# %%
import pandas as pd

df = pd.read_csv("student-mat.csv")

# %%
df.head()

# %%
grouped_data = df.groupby("sex")["famrel"]

# %%
grouped_data2 = grouped_data.sum()

# %%
import matplotlib.pyplot as plt

grouped_data2.plot(kind="bar", color=["pink", "blue"])
plt.title("Relationships")
plt.xlabel("Sex")
plt.ylabel("Family Score")
plt.show()
